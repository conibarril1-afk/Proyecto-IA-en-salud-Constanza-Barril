# %% [markdown]
# # Analisis principal
# Este notebook resume el flujo principal del proyecto de IA en salud.

# %%
# Ejemplo de importaciones base
import numpy as np
import pandas as pd
print('Notebook listo para ejecutar el pipeline')
